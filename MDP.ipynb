# %% [markdown]
# <a href="https://colab.research.google.com/github/Kanghb0628/Project_MDP/blob/main/MDP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# !pip install -r yolov5/requirements.txt  # install dependencies
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16656, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 16656 (delta 1), reused 5 (delta 0), pack-reused 16649
# Receiving objects: 100% (16656/16656), 15.12 MiB | 15.52 MiB/s, done.
# Resolving deltas: 100% (11438/11438), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 36.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 40.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="your api key")
project = rf.workspace("your name").project("your project name")
version = project.version("your version")
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to facecheck-4 in yolov5pytorch:: 100%|██████████| 618/618 [00:00<00:00, 4569.53it/s]

# %%
from glob import glob
train_img_list = glob('/content/your project name/train/images/*.jpg')
valid_img_list = glob('/content/your project name/valid/images/*.jpg')
test_img_list = glob('/content/your project name/test/images/*.jpg')
print(len(train_img_list), len(valid_img_list), len(test_img_list))
# Out:
# 258 25 20

# %%
# !python /content/yolov5/train.py --img 70 --batch 10 --epochs 115 --data /content/your project name/data.yaml --weights yolov5x.pt --name result_jetbot --cfg /content/yolov5/models/yolov5x.yaml
# Out:
# 2024-06-04 00:58:46.877431: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-04 00:58:46.877508: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-04 00:58:47.038108: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python /content/yolov5/detect.py --source=/content/filename --weights=/content/yolov5/runs/train/result_jetbot/weights/best.pt
# Out:
# detect: weights=['/content/yolov5/runs/train/result_jetbot/weights/best.pt'], source=/content/output.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-318-gc0380fd8 Python-3.10.12 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# YOLOv5x summary: 322 layers, 86186872 parameters, 0 gradients, 203.8 GFLOPs
# video 1/1 (1/836) /content/output.mp4: 640x640 2 KHBs, 3856.3ms
# video 1/1 (2/836) /content/output.mp4: 640x640 2 KHBs, 5325.4ms
# video 1/1 (3/836) /content/output.mp4: 640x640 2 KHBs, 4275.6ms
# video 1/1 (4/836) /content/output.mp4: 640x640 2 KHBs, 3720.1ms
# ...
